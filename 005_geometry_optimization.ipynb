# %%
# %pip install ase # Работа с 3D данными молекул
# %pip install xtb # Оптимизация конформаций с помощью полуэмпирического потенциала
# %pip install pyscf # HF, DFT, post-HF методы
# %pip install pyberny # Оптимизация конформаций для pyscf

# %%
# Знакомимся с ASE
from ase.io import read, write
from ase.visualize import view

# %%
# Оптимизация
from xtb.ase.calculator import XTB
from ase.optimize import BFGS

# %%
from pyscf import gto, scf, dft
from pyscf.geomopt.berny_solver import optimize
import numpy as np

# %%
# Ещё один способ визуализации данных
mol = read("./data/CC(C)(C)C(=O)C(Oc1ccc(Cl)cc1)n1ccnc1_000000.xyz")
view(mol, viewer="x3d")
# Out:
# <html>
#
#  <head>
#
#   <title>ASE atomic visualization</title>
#
#   <link rel="stylesheet" type="text/css"
#
#    href="https://www.x3dom.org/x3dom/release/x3dom.css">
#
#   </link>
#
#   <script type="text/javascript"
#
#    src="https://www.x3dom.org/x3dom/release/x3dom.js">
#
#   </script>
#
#  </head>
#
#  <body>
#
#   <X3D>
#
#    <Scene>
#
#     <Transform translation="-3.55 0.79 -0.79">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-2.12 0.74 -0.23">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-1.49 2.04 -0.74">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-2.22 0.70 1.26">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-1.41 -0.42 -0.79">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-2.00 -1.13 -1.62">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 0.051 0.051" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.66">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-0.03 -0.85 -0.47">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="0.63 -0.08 0.46">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 0.051 0.051" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.66">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="1.84 0.56 0.37">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="2.27 1.27 1.47">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="3.49 1.94 1.45">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="4.28 1.90 0.33">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="5.82 2.78 0.37">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.122 0.941 0.122" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.02">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="3.88 1.21 -0.77">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="2.65 0.54 -0.73">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-0.14 -2.26 -0.04">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.188 0.314 0.973" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.71">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-0.57 -3.26 -0.83">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-0.52 -4.43 -0.08">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-0.07 -4.11 1.14">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.188 0.314 0.973" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.71">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="0.16 -2.78 1.15">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-4.20 0.04 -0.33">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 1.000 1.000" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.31">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-3.46 0.67 -1.89">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 1.000 1.000" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.31">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-3.98 1.81 -0.64">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 1.000 1.000" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.31">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-0.41 2.00 -0.70">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 1.000 1.000" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.31">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-1.94 2.90 -0.20">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 1.000 1.000" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.31">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-1.82 2.12 -1.82">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 1.000 1.000" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.31">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-3.19 1.10 1.60">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 1.000 1.000" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.31">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-1.43 1.27 1.78">
#
#      <Sh

# %%
# Read xyz file
mol = read("./data/CC(C)(C)C(=O)C(Oc1ccc(Cl)cc1)n1ccnc1_000000.xyz")

# Attach xTB calculator
calc = XTB(method="GFN2-xTB")  
mol.calc = calc

# Optimize geometry
from ase.optimize import BFGS
dyn = BFGS(mol)
dyn.run(fmax=0.05)   # optimization until forces < 0.05 eV/Å

# Save optimized structure
write("optimized.xyz", mol)
# Out:
#       Step     Time          Energy         fmax
# BFGS:    0 01:41:33    -1613.184951        3.6684
# BFGS:    1 01:41:34    -1613.565960        3.8848
# BFGS:    2 01:41:35    -1613.688340        1.6500
# BFGS:    3 01:41:36    -1613.755555        0.7042
# BFGS:    4 01:41:37    -1613.801541        0.3809
# BFGS:    5 01:41:37    -1613.840183        0.5672
# BFGS:    6 01:41:38    -1613.870782        0.4051
# BFGS:    7 01:41:39    -1613.895336        0.3420
# BFGS:    8 01:41:39    -1613.915485        0.2709
# BFGS:    9 01:41:40    -1613.931219        0.2977
# BFGS:   10 01:41:41    -1613.943979        0.2128
# BFGS:   11 01:41:41    -1613.955249        0.2438
# BFGS:   12 01:41:42    -1613.967211        0.2132
# BFGS:   13 01:41:43    -1613.980122        0.2759
# BFGS:   14 01:41:43    -1613.991844        0.2206
# BFGS:   15 01:41:44    -1614.001391        0.2099
# BFGS:   16 01:41:45    -1614.009529        0.2537
# BFGS:   17 01:41:46    -1614.016748        0.2454
# BFGS:   18 01:41:46    -1614.022549        0.1515
# BFGS:   19 01:41:47    -1614.026700        0.1030
# BFGS:   20 01:41:48    -1614.030069        0.1230
# BFGS:   21 01:41:48    -1614.033824        0.1727
# BFGS:   22 01:41:49    -1614.038746        0.1595
# BFGS:   23 01:41:50    -1614.044632        0.1706
# BFGS:   24 01:41:50    -1614.050192        0.1502
# BFGS:   25 01:41:51    -1614.054188        0.1165
# BFGS:   26 01:41:51    -1614.056922        0.1003
# BFGS:   27 01:41:52    -1614.059488        0.1077
# BFGS:   28 01:41:53    -1614.062572        0.1285
# BFGS:   29 01:41:53    -1614.066000        0.1294
# BFGS:   30 01:41:54    -1614.069277        0.1322
# BFGS:   31 01:41:54    -1614.072179        0.1169
# BFGS:   32 01:41:55    -1614.074794        0.1293
# BFGS:   33 01:41:56    -1614.077316        0.1015
# BFGS:   34 01:41:56    -1614.079842        0.1319
# BFGS:   35 01:41:57    -1614.082313        0.1117
# BFGS:   36 01:41:58    -1614.084609        0.1249
# BFGS:   37 01:41:58    -1614.086578        0.0926
# BFGS:   38 01:41:59    -1614.088181        0.0782
# BFGS:   39 01:41:59    -1614.089695        0.1084
# BFGS:   40 01:42:00    -1614.091466        0.1253
# BFGS:   41 01:42:00    -1614.093533        0.1346
# BFGS:   42 01:42:01    -1614.095521        0.0819
# BFGS:   43 01:42:02    -1614.097109        0.0824
# BFGS:   44 01:42:02    -1614.098392        0.0823
# BFGS:   45 01:42:03    -1614.099629        0.1116
# BFGS:   46 01:42:03    -1614.100872        0.0928
# BFGS:   47 01:42:04    -1614.102091        0.0655
# BFGS:   48 01:42:04    -1614.103140        0.0606
# BFGS:   49 01:42:05    -1614.103835        0.0640
# BFGS:   50 01:42:05    -1614.104654        0.0464

# %%
mol2 = read("optimized.xyz")
view(mol2, viewer="x3d")
# Out:
# <html>
#
#  <head>
#
#   <title>ASE atomic visualization</title>
#
#   <link rel="stylesheet" type="text/css"
#
#    href="https://www.x3dom.org/x3dom/release/x3dom.css">
#
#   </link>
#
#   <script type="text/javascript"
#
#    src="https://www.x3dom.org/x3dom/release/x3dom.js">
#
#   </script>
#
#  </head>
#
#  <body>
#
#   <X3D>
#
#    <Scene>
#
#     <Transform translation="-3.64 0.84 -0.72">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-2.18 0.78 -0.27">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-1.46 2.06 -0.73">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-2.12 0.60 1.25">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-1.50 -0.39 -0.98">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-2.02 -0.99 -1.88">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 0.051 0.051" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.66">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-0.06 -0.82 -0.58">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="0.52 -0.02 0.40">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 0.051 0.051" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.66">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="1.77 0.51 0.30">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="2.17 1.22 1.43">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="3.38 1.88 1.47">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="4.22 1.83 0.36">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="5.73 2.66 0.39">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.122 0.941 0.122" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.02">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="3.84 1.12 -0.77">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="2.62 0.46 -0.80">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-0.11 -2.19 -0.10">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.188 0.314 0.973" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.71">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-0.39 -3.31 -0.84">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-0.35 -4.35 0.03">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-0.05 -3.91 1.28">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.188 0.314 0.973" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.71">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="0.08 -2.62 1.18">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-4.17 -0.04 -0.38">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 1.000 1.000" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.31">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-3.71 0.89 -1.80">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 1.000 1.000" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.31">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-4.12 1.72 -0.29">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 1.000 1.000" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.31">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-0.42 2.08 -0.39">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 1.000 1.000" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.31">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-1.97 2.93 -0.32">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 1.000 1.000" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.31">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-1.48 2.13 -1.81">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 1.000 1.000" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.31">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-2.80 1.31 1.72">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 1.000 1.000" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.31">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-1.12 0.78 1.64">
#
#      <Sh

# %%
mol2 = read("optimized.xyz")
view(mol+mol2, viewer="x3d")
# Out:
# <html>
#
#  <head>
#
#   <title>ASE atomic visualization</title>
#
#   <link rel="stylesheet" type="text/css"
#
#    href="https://www.x3dom.org/x3dom/release/x3dom.css">
#
#   </link>
#
#   <script type="text/javascript"
#
#    src="https://www.x3dom.org/x3dom/release/x3dom.js">
#
#   </script>
#
#  </head>
#
#  <body>
#
#   <X3D>
#
#    <Scene>
#
#     <Transform translation="-3.55 0.79 -0.79">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-2.12 0.74 -0.23">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-1.49 2.04 -0.74">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-2.22 0.70 1.26">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-1.41 -0.42 -0.79">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-2.00 -1.13 -1.62">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 0.051 0.051" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.66">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-0.03 -0.85 -0.47">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="0.63 -0.08 0.46">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 0.051 0.051" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.66">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="1.84 0.56 0.37">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="2.27 1.27 1.47">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="3.49 1.94 1.45">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="4.28 1.90 0.33">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="5.82 2.78 0.37">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.122 0.941 0.122" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.02">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="3.88 1.21 -0.77">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="2.65 0.54 -0.73">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-0.14 -2.26 -0.04">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.188 0.314 0.973" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.71">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-0.57 -3.26 -0.83">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-0.52 -4.43 -0.08">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-0.07 -4.11 1.14">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.188 0.314 0.973" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.71">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="0.16 -2.78 1.15">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-4.20 0.04 -0.33">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 1.000 1.000" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.31">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-3.46 0.67 -1.89">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 1.000 1.000" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.31">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-3.98 1.81 -0.64">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 1.000 1.000" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.31">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-0.41 2.00 -0.70">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 1.000 1.000" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.31">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-1.94 2.90 -0.20">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 1.000 1.000" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.31">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-1.82 2.12 -1.82">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 1.000 1.000" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.31">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-3.19 1.10 1.60">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 1.000 1.000" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.31">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-1.43 1.27 1.78">
#
#      <Sh

# %%
# Read xyz file
adamantane = read("./data/Adamantane.sdf")

# %%
# Read xyz file
mol = read("./data/Adamantane.sdf")

# Attach xTB calculator
calc = XTB(method="GFN2-xTB")  
mol.calc = calc

# Optimize geometry
from ase.optimize import BFGS
dyn = BFGS(mol)
dyn.run(fmax=0.05)   # optimization until forces < 0.05 eV/Å

# Save optimized structure
write("optimized.xyz", mol)
# Out:
#       Step     Time          Energy         fmax
# BFGS:    0 02:03:22     -806.487866        0.5681
# BFGS:    1 02:03:23     -806.502497        0.2250
# BFGS:    2 02:03:23     -806.511743        0.2093
# BFGS:    3 02:03:24     -806.520403        0.1470
# BFGS:    4 02:03:24     -806.522114        0.0616
# BFGS:    5 02:03:24     -806.523164        0.0645
# BFGS:    6 02:03:25     -806.524034        0.0668
# BFGS:    7 02:03:25     -806.524483        0.0360

# %%
view(adamantane+mol, viewer="x3d")
# Out:
# <html>
#
#  <head>
#
#   <title>ASE atomic visualization</title>
#
#   <link rel="stylesheet" type="text/css"
#
#    href="https://www.x3dom.org/x3dom/release/x3dom.css">
#
#   </link>
#
#   <script type="text/javascript"
#
#    src="https://www.x3dom.org/x3dom/release/x3dom.js">
#
#   </script>
#
#  </head>
#
#  <body>
#
#   <X3D>
#
#    <Scene>
#
#     <Transform translation="-0.55 -0.62 -1.30">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="0.60 1.39 -0.30">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="1.10 -0.92 0.58">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-1.14 0.14 1.03">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="0.04 0.77 -1.60">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="0.55 -1.52 -0.72">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-1.69 -0.47 -0.27">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="1.69 0.47 0.27">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-0.55 1.52 0.72">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-0.04 -0.77 1.60">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-0.95 -1.05 -2.23">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 1.000 1.000" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.31">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="1.02 2.38 -0.52">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 1.000 1.000" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.31">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="1.88 -1.57 0.98">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 1.000 1.000" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.31">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-1.95 0.24 1.76">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 1.000 1.000" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.31">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="0.84 0.69 -2.34">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 1.000 1.000" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.31">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-0.73 1.43 -2.03">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 1.000 1.000" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.31">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="0.14 -2.52 -0.53">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 1.000 1.000" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.31">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="1.35 -1.65 -1.45">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 1.000 1.000" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.31">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-2.49 0.16 -0.68">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 1.000 1.000" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.31">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-2.13 -1.45 -0.07">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 1.000 1.000" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.31">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="2.51 0.38 -0.44">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 1.000 1.000" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.31">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="2.10 0.91 1.19">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 1.000 1.000" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.31">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-0.17 1.98 1.65">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 1.000 1.000" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.31">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-1.32 2.19 0.33">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 1.000 1.000" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.31">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-0.46 -1.76 1.83">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 1.000 1.000" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.31">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="0.34 -0.35 2.53">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 1.000 1.000" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.31">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-0.55 -0.61 -1.29">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="0.59 1.38 -0.30">
#
#      <Shap

# %%
# --- 1. Read xyz with ASE ---
mol = read("./data/Adamantane.sdf")

# --- 2. Build PySCF molecule from ASE Atoms ---
mol = gto.Mole()
mol.atom = "\n".join(
    f"{atom.symbol} {x} {y} {z}"
    for atom, (x, y, z) in zip(atoms, atoms.positions)
)
mol.basis = "sto-3g"    # choose basis set
mol.unit = "Angstrom"
mol.build()

# --- 3. Run HF optimization ---
mf = scf.RHF(mol)
mol_eq = optimize(mf)   # Pyberny optimizer

# --- 4. Extract final geometry ---
coords = mol_eq.atom_coords()
symbols = mol_eq.atom_symbols()

# --- 5. Make a new ASE Atoms object ---
from ase import Atoms
atoms_opt = Atoms(symbols=symbols, positions=coords)

# --- 6. Save & visualize with ASE ---
write("optimized_dft.xyz", atoms_opt)
atoms_opt.write("optimized_dft.traj")
# Out:
# Geometry optimization cycle 1
# Cartesian coordinates (Angstrom)
#  Atom        New coordinates             dX        dY        dZ
#    C  -3.639873   0.840550  -0.717384    0.000000  0.000000  0.000000
#    C  -2.175011   0.777034  -0.271913    0.000000  0.000000  0.000000
#    C  -1.456924   2.058393  -0.727531    0.000000  0.000000  0.000000
#    C  -2.119679   0.604932   1.249853    0.000000  0.000000  0.000000
#    C  -1.504502  -0.386566  -0.981645    0.000000  0.000000  0.000000
#    O  -2.020679  -0.991013  -1.884441    0.000000  0.000000  0.000000
#    C  -0.060131  -0.821903  -0.580987    0.000000  0.000000  0.000000
#    O   0.515747  -0.017830   0.397518    0.000000  0.000000  0.000000
#    C   1.774089   0.514762   0.299141    0.000000  0.000000  0.000000
#    C   2.173711   1.222441   1.434218    0.000000  0.000000  0.000000
#    C   3.384898   1.877076   1.466897    0.000000  0.000000  0.000000
#    C   4.216272   1.825948   0.356873    0.000000  0.000000  0.000000
#   Cl   5.730767   2.658227   0.390954    0.000000  0.000000  0.000000
#    C   3.837365   1.117280  -0.769391    0.000000  0.000000  0.000000
#    C   2.618815   0.457638  -0.799590    0.000000  0.000000  0.000000
#    N  -0.112042  -2.189648  -0.098743    0.000000  0.000000  0.000000
#    C  -0.388945  -3.307190  -0.843682    0.000000  0.000000  0.000000
#    C  -0.345485  -4.354534   0.029092    0.000000  0.000000  0.000000
#    N  -0.050810  -3.909325   1.279570    0.000000  0.000000  0.000000
#    C   0.075903  -2.619455   1.177302    0.000000  0.000000  0.000000
#    H  -4.173851  -0.044273  -0.380846    0.000000  0.000000  0.000000
#    H  -3.712060   0.892169  -1.800510    0.000000  0.000000  0.000000
#    H  -4.122885   1.717253  -0.293084    0.000000  0.000000  0.000000
#    H  -0.424119   2.084760  -0.392848    0.000000  0.000000  0.000000
#    H  -1.966068   2.926603  -0.316860    0.000000  0.000000  0.000000
#    H  -1.478421   2.134137  -1.813358    0.000000  0.000000  0.000000
#    H  -2.796943   1.313059   1.719882    0.000000  0.000000  0.000000
#    H  -1.122145   0.777013   1.635063    0.000000  0.000000  0.000000
#    H  -2.429355  -0.400192   1.525498    0.000000  0.000000  0.000000
#    H   0.507140  -0.823111  -1.523676    0.000000  0.000000  0.000000
#    H   1.511831   1.247971   2.284816    0.000000  0.000000  0.000000
#    H   3.683047   2.430785   2.342761    0.000000  0.000000  0.000000
#    H   4.486208   1.083965  -1.630237    0.000000  0.000000  0.000000
#    H   2.357021  -0.089554  -1.690864    0.000000  0.000000  0.000000
#    H  -0.596477  -3.252016  -1.892396    0.000000  0.000000  0.000000
#    H  -0.494285  -5.398872  -0.161795    0.000000  0.000000  0.000000
#    H   0.317873  -1.956511   1.982343    0.000000  0.000000  0.000000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[26], line 16
#      14 # --- 3. Run HF optimization ---
#      15 mf = scf.RHF(mol)
# ---> 16 mol_eq = optimize(mf)   # Pyberny optimizer
#      18 # --- 4. Extract final geometry ---
#      19 coords = mol_eq.atom_coords()
#
# File ~/anaconda3/envs/p4env/lib/python3.10/site-packages/pyscf/geomopt/berny_solver.py:175, in optimize(method, assert_convergence, include_ghost, callback, **kwargs)
#     158 def optimize(method, assert_convergence=ASSERT_CONV,
#     159              include_ghost=INCLUDE_GHOST, callback=None, **kwargs):
#     160     '''Optimize geometry with pyberny for the given method.
#     161
#     162     To adjust the convergence threshold, parameters can be set in kwargs as
#    (...)
#     173         newmol = berny_solver.optimize(method, **conv_params)
#     174     '''
# --> 175     return kernel(method, assert_convergence, include_ghost, callback,
#     176                   **kwargs)[1]
#
# File ~/anaconda3/envs/p4env/lib/python3.10/site-packages/pyscf/geomopt/berny_solver.py:143, in kernel(method, assert_convergence, include_ghost, callback, **kwargs)
#     140     geom.coords = symmetrize(mol, geom.coords)
#     142 mol.set_geom_(_geom_to_atom(mol, geom, include_ghost), unit='Bohr')
# --> 143 energy, gradients = g_scanner(mol)
#     144 log.note('cycle %d: E = %.12g  dE = %g  norm(grad) = %g', cycle+1,
#     145          energy, energy - e_last, numpy.linalg.norm(gradients))
#     146 e_last = energy
#
# File ~/anaconda3/envs/p4env/lib/python3.10/site-packages/pyscf/grad/rhf.py:261, in SCF_GradScanner.__call__(self, mol_or_geom, **kwargs)
#     259 self.reset(mol)
#     260 mf_scanner = self.base
# --> 261 e_tot = mf_scanner(mol)
#     263 if isinstance(mf_scanner, hf.KohnShamDFT):
#     264     if getattr(self, 'grids', None):
#
# File ~/anaconda3/envs/p4env/lib/python3.10/site-packages/pyscf/scf/hf.py:1575, in SCF_Scanner.__call__(self, mol_or_geom, **kwargs)
#    1573         dm0 = self.from_chk(self.chkfile)
#    1574 self.mo_coeff = None  # To avoid last mo_coeff being used by SOSCF
# -> 1575 e_tot = self.kernel(dm0=dm0, **kwargs)
#    1576 self._last_mol_fp = mol.ao_loc
#    1577 return e_tot
#
# File <string>:2, in kernel(self, dm0, **kwargs)
#
# File ~/anaconda3/envs/p4env/lib/python3.10/site-packages/pyscf/scf/hf.py:2000, in SCF.scf(self, dm0, **kwargs)
#    1995 self.build(self.mol)
#    1997 if self.max_cycle > 0 or self.mo_coeff is None:
#    1998     self.converged, self.e_tot, \
#    1999             self.mo_energy, self.mo_coeff, self.mo_occ = \
# -> 2000             kernel(self, self.conv_tol, self.conv_tol_grad,
#    2001                    dm0=dm0, callback=self.callback,
#    2002                    conv_check=self.conv_check, **kwargs)
#    2003 else:
#    2004     # Avoid to update SCF orbitals in the non-SCF initialization
#    2005     # (issue #495).  But run regular SCF for initial guess if SCF was
#    2006     # not initialized.
#    2007     self.e_tot = kernel(self, self.conv_tol, self.conv_tol_grad,
#    2008                         dm0=dm0, callback=self.callback,
#    2009                         conv_check=self.conv_check, **kwargs)[1]
#
# File ~/anaconda3/envs/p4env/lib/python3.10/site-packages/pyscf/scf/hf.py:175, in kernel(mf, conv_tol, conv_tol_grad, dump_chk, dm0, callback, conv_check, **kwargs)
#     172 dm_last = dm
#     173 last_hf_e = e_tot
# --> 175 fock = mf.get_fock(h1e, s1e, vhf, dm, cycle, mf_diis, fock_last=fock_last)
#     176 mo_energy, mo_coeff = mf.eig(fock, s1e)
#     177 mo_occ = mf.get_occ(mo_energy, mo_coeff)
#
# File ~/anaconda3/envs/p4env/lib/python3.10/site-packages/pyscf/scf/hf.py:1108, in get_fock(mf, h1e, s1e, vhf, dm, cycle, diis, diis_start_cycle, level_shift_factor, damp_factor, fock_last)
#    1106     f = damping(f, fock_last, damp_factor)
#    1107 if diis is not None and cycle >= diis_start_cycle:
# -> 1108     f = diis.update(s1e, dm, f, mf, h1e, vhf, f_prev=fock_last)
#    1109 if abs(level_shift_factor) > 1e-4:
#    1110     f = level_shift(s1e, dm*.5, f, level_shift_factor)
#
# File ~/anaconda3/envs/p4env/lib/python3.10/site-packages/pyscf/scf/diis.py:49, in CDIIS.update(self, s, d, f, *args, **kwargs)
#      48 def update(self, s, d, f, *args, **kwargs):
# ---> 49     errvec = get_err_vec(s, d, f, self.Corth)
#      50     logger.debug1(self, 'diis-norm(errvec)=%g', numpy.linalg.norm(errvec))
#      51     f_prev = kwargs.get('f_prev', None)
#
# File ~/anaconda3/envs/p4env/lib/python3.10/site-packages/pyscf/scf/diis.py:123, in get_err_vec(s, d, f, Corth)
#     121     return get_err_vec_orig(s, d, f)
#     122 else:
# --> 123     return get_err_vec_orth(s, d, f, Corth)
#
# File ~/anaconda3/envs/p4env/lib/python3.10/site-packages/pyscf/scf/diis.py:97, in get_err_vec_orth(s, d, f, Corth)
#      94     sym_forbid = orbsym[:,None] != orbsym
#      96 if isinstance(f, numpy.ndarray) and f.ndim == 2:
# ---> 97     sdf = reduce(lib.dot, (Corth.conj().T, s, d, f, Corth))
#      98     if orbsym is not None:
#      99         sdf[sym_forbid] = 0
#
# File ~/anaconda3/envs/p4env/lib/python3.10/site-packages/pyscf/lib/numpy_helper.py:777, in dot(a, b, alpha, c, beta)
#     775 if atype == numpy.float64 and btype == numpy.float64:
#     776     if c is None or c.dtype == numpy.float64:
# --> 777         return ddot(a, b, alpha, c, beta)
#     778     else:
#     779         cr = numpy.asarray(c.real, order='C')
#
# File ~/anaconda3/envs/p4env/lib/python3.10/site-packages/pyscf/lib/numpy_helper.py:714, in ddot(a, b, alpha, c, beta)
#     711 else:
#     712     assert (c.shape == (m,n))
# --> 714 return _dgemm(trans_a, trans_b, m, n, k, a, b, c, alpha, beta)
#
# File ~/anaconda3/envs/p4env/lib/python3.10/site-packages/pyscf/lib/numpy_helper.py:849, in _dgemm(trans_a, trans_b, m, n, k, a, b, c, alpha, beta, offseta, offsetb, offsetc)
#     846 assert (b.flags.c_contiguous)
#     847 assert (c.flags.c_contiguous)
# --> 849 _np_helper.NPdgemm(ctypes.c_char(trans_b.encode('ascii')),
#     850                    ctypes.c_char(trans_a.encode('ascii')),
#     851                    ctypes.c_int(n), ctypes.c_int(m), ctypes.c_int(k),
#     852                    ctypes.c_int(b.shape[1]), ctypes.c_int(a.shape[1]),
#     853                    ctypes.c_int(c.shape[1]),
#     854                    ctypes.c_int(offsetb), ctypes.c_int(offseta),
#     855                    ctypes.c_int(offsetc),
#     856                    b.ctypes.data_as(ctypes.c_void_p),
#     857                    a.ctypes.data_as(ctypes.c_void_p),
#     858                    c.ctypes.data_as(ctypes.c_void_p),
#     859                    ctypes.c_double(alpha), ctypes.c_double(beta))
#     860 return c
#
# KeyboardInterrupt:

# %%
from ase.visualize import view
view(adamantane+mol, viewer="x3d")   # interactive 3D view in notebook

# %%
# --- 1. Read xyz with ASE ---
mol = read("./data/Adamantane.sdf")   # ASE Atoms object

# --- 2. Build PySCF molecule from ASE Atoms ---
mol = gto.Mole()
mol.atom = "\n".join(
    f"{atom.symbol} {x} {y} {z}"
    for atom, (x, y, z) in zip(atoms, atoms.positions)
)
mol.basis = "def2-svp"    # Basis set
mol.unit = "Angstrom"
mol.build()

# --- 3. Set up DFT calculation ---
mf = dft.RKS(mol)
mf.xc = "wb97x-d"   # ωB97X-D functional

# --- 4. Geometry optimization (Pyberny) ---
mol_eq = optimize(mf)

# --- 5. Extract final geometry ---
coords = mol_eq.atom_coords()
symbols = mol_eq.atom_symbols()
atoms_opt_dft = Atoms(symbols=symbols, positions=coords)

# --- 6. Save & visualize ---
write("wb97xd_opt.xyz", atoms_opt_dft)

# %%
from ase.visualize import view
view(adamantane+atoms_opt_dft, viewer="x3d")   # interactive 3D view in notebook
